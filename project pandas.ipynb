# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("drinks.csv")
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
df["beer_servings"]+df["spirit_servings"]+df["wine_servings"]
# Out:
# 0        0
# 1      275
# 2       39
# 3      695
# 4      319
#       ...
# 188    436
# 189    114
# 190      6
# 191     55
# 192     86
# Length: 193, dtype: int64

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df["Total"]=df["beer_servings"]+df["spirit_servings"]+df["wine_servings"]
df["Total"]
# Out:
# 0        0
# 1      275
# 2       39
# 3      695
# 4      319
#       ...
# 188    436
# 189    114
# 190      6
# 191     55
# 192     86
# Name: Total, Length: 193, dtype: int64

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent  Total
# 0                             0.0           Asia      0
# 1                             4.9         Europe    275
# ...

# %%
df[["beer_servings","spirit_servings","wine_servings","continent","Total"]]
# Out:
#      beer_servings  spirit_servings  wine_servings      continent  Total
# 0                0                0              0           Asia      0
# 1               89              132             54         Europe    275
# 2               25                0             14         Africa     39
# 3              245              138            312         Europe    695
# 4              217               57             45         Africa    319
# ..             ...              ...            ...            ...    ...
# 188            333              100              3  South America    436
# 189            111                2              1           Asia    114
# 190              6                0              0           Asia      6
# 191             32               19              4         Africa     55
# 192             64               18              4         Africa     86
#
# [193 rows x 5 columns]

# %%
df["continent"].value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
df.groupby("continent")["Total"].mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
explode=[0,0,0,0,0,0.1]
df["continent"].value_counts().plot(figsize=(5,5),kind="pie",autopct='%.2f%%',explode=explode)
plt.show()

# %%
sns.distplot(df["total_litres_of_pure_alcohol"])                      
plt.show()

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
#histogram plot
df["beer_servings"].hist(bins=6)
plt.show()
